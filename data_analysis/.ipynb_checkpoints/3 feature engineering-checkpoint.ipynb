# %% [markdown]
# Task list:
# 1. cbdDistance - new column to find distance from cbd
# 2. beachDistance - new column to find distance from nearest beach
# 3. find school ratings - new columns to replace primary and secondary
# 4. categorical -> to numerical
# 5. soldMonth, soldYear
# 6. latitude and longitude
# 7. variable selection
# - oulier detection

# %%
import pandas as pd
pd.set_option("max_colwidth", None)
pd.set_option("max_seq_items", None)
import numpy as np

import geopandas as gpd
from shapely.geometry import Point
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

from sklearn.feature_selection import VarianceThreshold
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
path = '/Users/tristangarcia/desktop/hp-pred_data/data/wa_data/'

# %%
train = pd.read_pickle(f'{path}wa_train_clean.pkl')
test = pd.read_pickle(f'{path}wa_validation_clean.pkl')    # validation set

# %%
train.shape
# Out:
# (81088, 39)

# %%
train.head()
# Out:
#       listingId unitNumber streetNumber            street       suburb state  \
# 0  2.013763e+09        NaN            7      jubata court   maida vale    wa
# 1  2.019337e+09        NaN            9    syndicate link  lake coogee    wa
# 2  2.014115e+09        NaN          107     bulong avenue    redcliffe    wa
# 3  2.018923e+09        NaN           24    ferryside road       butler    wa
# 4  2.019303e+09        NaN           31  lady douglas way   pegs creek    wa
#
#    postcode  bathrooms  bedrooms  parking  ...  suburb_entryLevelPrice  \
# 0    6057.0          2         4        2  ...                590000.0
# 1    6166.0          2         3        2  ...                485000.0
# 2    6104.0          1         3        1  ...                410000.0
# 3    6036.0          2         4        2  ...                510000.0
# 4    6714.0          1         3        4  ...                400000.0
#
#    suburb_luxuryLevelPrice                    primary primaryDistance  \
# 0                1850000.0  maida vale primary school     1016.420520
# 1                 914000.0      coogee primary school     1540.964325
# 2                 830000.0   redcliffe primary school      509.498088
# 3                 845000.0      butler primary school      808.852983
# 4                 640000.0  pegs creek primary school      779.732155
#
#   primaryType                        secondary secondaryDistance  \
# 0  government     darling range sports college       2218.034622
# 1  government             divine mercy college       4120.780071
# 2  government  alta-1 college - belmont campus       1972.597513
# 3  government                   butler college       1707.715594
# 4  government      karratha senior high school       1856.050617
#
#    secondaryType  \
# 0     government
# 1        private
# 2        private
# 3     government
# 4     government
#
#                                                                     listingUrl  \
# 0       https://www.domain.com.au/7-jubata-court-maida-vale-wa-6057-2013763410
# 1    https://www.domain.com.au/9-syndicate-link-lake-coogee-wa-6166-2019337055
# 2     https://www.domain.com.au/107-bulong-avenue-redcliffe-wa-6104-2014115350
# 3        https://www.domain.com.au/24-ferryside-road-butler-wa-6036-2018923325
# 4  https://www.domain.com.au/31-lady-douglas-way-pegs-creek-wa-6714-2019302960
#
#    soldPrice
# 0   512500.0
# 1   914000.0
# 2   452000.0
# 3   600000.0
# 4   525000.0
#
# [5 rows x 39 columns]

# %%
train.columns
# Out:
# Index(['listingId', 'unitNumber', 'streetNumber', 'street', 'suburb', 'state',
#        'postcode', 'bathrooms', 'bedrooms', 'parking', 'landArea', 'latitude',
#        'longitude', 'features', 'agency', 'propertyType', 'promoLevel',
#        'soldMonth', 'soldYear', 'daysListed', 'inspectionsCount', 'isRural',
#        'hasDescription', 'hasFloorplan', 'hasDisplayPrice', 'hasPhoto',
#        'photoCount', 'suburb_medianPrice', 'suburb_medianRentPrice',
#        'suburb_entryLevelPrice', 'suburb_luxuryLevelPrice', 'primary',
#        'primaryDistance', 'primaryType', 'secondary', 'secondaryDistance',
#        'secondaryType', 'listingUrl', 'soldPrice'],
#       dtype='object')

# %% [markdown]
# # Outlier removal

# %%
train['bathrooms'].value_counts()
# Out:
# bathrooms
# 2     46030
# 1     30341
# 3      3972
# 4       527
# 5        94
# 0        66
# 6        32
# 8        10
# 7         8
# 11        2
# 10        2
# 16        1
# 9         1
# 17        1
# 15        1
# Name: count, dtype: int64

# %% [markdown]
# # School ICSEA ratings

# %%
school_path = '/Users/tristangarcia/desktop/hp-pred_data/school/'
school_icsea = pd.read_csv(f'{school_path}school_icsea.csv')
school_loc = pd.read_csv(f'{school_path}school_location.csv')

# %%
#### Preprocessing school_icsea data ####

# Dropping missing values
school_icsea.dropna(inplace=True)
# Subsetting columns
school_icsea = school_icsea[['School Name', 'Suburb', 'State','School Sector', 'School Type', 'ICSEA']]
# Lowercasing all string values
school_icsea = school_icsea.map(lambda x: x.lower() if isinstance(x,str) else x)
# Changing 'Independent' sector to 'private'
school_icsea['School Sector'] = school_icsea['School Sector'].map(lambda x: 'private' if x=='independent' else x)
# Renaming columns
school_icsea.rename(columns={'School Name':'school','Suburb':'suburb','State':'state',
                        'School Sector':'sector','School Type':'type','ICSEA':'icsea'}, inplace=True)

# %%
#### Preprocessing school_loc data ####

# Dropping missing values
school_loc.dropna(inplace=True)
# Subsetting columns
school_loc = school_loc[['School Name', 'Suburb', 'State','School Sector', 'School Type', 'Latitude', 'Longitude']]
# Lowercasing all string values
school_loc = school_loc.map(lambda x: x.lower() if isinstance(x,str) else x)
# Changing 'Independent' sector to 'private'
school_loc['School Sector'] = school_loc['School Sector'].map(lambda x: 'private' if x=='independent' else x)
# Renaming columns
school_loc.rename(columns={'School Name':'school','Suburb':'suburb','State':'state','School Sector':'sector',
                           'School Type':'type','Latitude':'latitude','Longitude':'longitude'}, inplace=True)

# %%
school_loc.shape
# Out:
# (10926, 7)

# %%
def get_school_icsea(row, school_table1, school_table2, school, suburb):
    # Composite key: school name and suburb
    key = (suburb, school)
    # Check if key exists in the school_table index
    if key in school_table1.index:
        # Return ICSEA of the school using the composite key
        return school_table1.loc[key, 'icsea']
    elif school in school_table2.index:
        return school_table2.loc[school, 'icsea']
    # Return NaN if the school-suburb combination is not found
    else:
        return np.nan


def get_icsea(df, schools, school_type):
    # Filter the schools based on the given school type
    school_table = schools[(schools['state'] == 'wa') &
                           ((schools['type'] == school_type) |
                            (schools['type'] == 'combined'))][['school', 'suburb', 'icsea']]
    # Set the composite key as the index
    school_table1 = school_table.set_index(['suburb','school'])
    school_table2 = school_table.set_index(['school'])

    
    # Create new ICSEA column for the data
    df[f'{school_type}ICSEA'] = df.apply(
        lambda row: get_school_icsea(row, school_table1, school_table2, row[school_type], row['suburb']), axis=1
    )
    
    return df

# %%
# Creating primaryICSEA and secondaryICSEA columns for train and test
train = get_icsea(train, schools, 'primary')
train = get_icsea(train, schools, 'secondary')
test = get_icsea(test, schools, 'primary')
test = get_icsea(test, schools, 'secondary')

# %%
train[train['primaryICSEA'].apply(lambda x: isinstance(x,pd.Series))]
# Out:
#           listingId unitNumber streetNumber                 street  \
# 155    2.017902e+09        NaN          825             beela road
# 234    2.019008e+09         17           15          hillview road
# 326    2.019233e+09        NaN           22      oleander crescent
# 378    2.018376e+09        NaN           15          nemesis place
# 425    2.019389e+09        NaN           17               ray road
# ...             ...        ...          ...                    ...
# 80544  2.016680e+09        NaN         101a            raglan road
# 80668  2.019218e+09        NaN           33           assen street
# 80756  2.019079e+09          2           26  little walcott street
# 80893  2.019435e+09        NaN           17            robinia way
# 81012  2.019351e+09        NaN          16a           stockman way
#
#                  suburb state  postcode  bathrooms  bedrooms  parking  ...  \
# 155               beela    wa    6224.0          1         3        0  ...
# 234          pegs creek    wa    6714.0          1         1        1  ...
# 326            rangeway    wa    6530.0          1         3        1  ...
# 378    south kalgoorlie    wa    6430.0          1         3        1  ...
# 425           swan view    wa    6056.0          2         4        2  ...
# ...                 ...   ...       ...        ...       ...      ...  ...
# 80544      mount lawley    wa    6050.0          2         3        2  ...
# 80668          rangeway    wa    6530.0          1         3        1  ...
# 80756       north perth    wa    6006.0          1         1        1  ...
# 80893    kangaroo gully    wa    6255.0          2         3        4  ...
# 81012        cannington    wa    6107.0          2         4        4  ...
#
#                            primary  primaryDistance  primaryType  \
# 155            st michael's school         6.850389     catholic
# 234       st paul's primary school      1012.780703     catholic
# 326               st john's school       137.213161     catholic
# 378             st joseph's school      1099.337571     catholic
# 425            st anthony's school       729.717994     catholic
# ...                            ...              ...          ...
# 80544  sacred heart primary school       545.105577     catholic
# 80668             st john's school       964.059163     catholic
# 80756     st paul's primary school       398.165528     catholic
# 80893           st brigid's school      4045.961233     catholic
# 81012           st joseph's school       515.199302     catholic
#
#                                       secondary secondaryDistance  \
# 155                   harvey senior high school      16164.416646
# 234                 karratha senior high school       1959.722246
# 326             champion bay senior high school       1244.352967
# 378    kalgoorlie-boulder community high school        487.187690
# 425                swan view senior high school        383.781950
# ...                                         ...               ...
# 80544              seda college wa (west perth)        873.950837
# 80668           champion bay senior high school        652.866853
# 80756           mount lawley senior high school       1072.689607
# 80893               manjimup senior high school      29670.319741
# 81012              cannington community college        659.452849
#
#       secondaryType  \
# 155      government
# 234      government
# 326      government
# 378      government
# 425      government
# ...             ...
# 80544       private
# 80668    government
# 80756    government
# 80893    government
# 81012    government
#
#                                                                                 listingUrl  \
# 155                      https://www.domain.com.au/825-beela-road-beela-wa-6224-2017902158
# 234            https://www.domain.com.au/17-15-hillview-road-pegs-creek-wa-6714-2019007649
# 326             https://www.domain.com.au/22-oleander-crescent-rangeway-wa-6530-2019233224
# 378         https://www.domain.com.au/15-nemesis-place-south-kalgoorlie-wa-6430-2018376493
# 425                     https://www.domain.com.au/17-ray-road-swan-view-wa-6056-2019389173
# ...                                                                                    ...
# 80544           https://www.domain.com.au/101a-raglan-road-mount-lawley-wa-6050-2016679838
# 80668                https://www.domain.com.au/33-assen-street-rangeway-wa-6530-2019217625
# 80756  https://www.domain.com.au/2-26-little-walcott-street-north-perth-wa-6006-2019078634
# 80893           https://www.domain.com.au/17-robinia-way-kangaroo-gully-wa-6255-2019435091
# 81012             https://www.domain.com.au/16a-stockman-way-cannington-wa-6107-2019351115
#
#        soldPrice  \
# 155     600000.0
# 234     200000.0
# 326     303000.0
# 378     230101.0
# 425     862000.0
# ...          ...
# 80544  1200000.0
# 80668   295000.0
# 80756   357000.0
# 80893   850000.0
# 81012   617000.0
#
#                                                                                                                                                                                                                                                                                                   primaryICSEA  \
# 155                                                                                                                                                                                                             school
# st michael's school    1093.0
# st michael's school    1040.0
# Name: icsea, dtype: float64
# 234                                                                                                                                                                                                   school
# st paul's primary school    1153.0
# st paul's primary school    1015.0
# Name: icsea, dtype: float64
# 326                                                                                                                                                                                                                   school
# st john's school    1119.0
# st john's school     907.0
# Name: icsea, dtype: float64
# 378    school
# st joseph's school    1000.0
# st joseph's school     781.0
# st joseph's school     908.0
# st joseph's school    1022.0
# st joseph's school    1022.0
# st joseph's school    1084.0
# st joseph's school     947.0
# st joseph's school     976.0
# st joseph's school     708.0
# Name: icsea, dtype: float64
# 425                                                                                                                                                                                                             school
# st anthony's school    1036.0
# st anthony's school    1049.0
# Name: icsea, dtype: float64
# ...                                                                                                                                                                                                                                                                                                        ...
# 80544                                                                                                                                                                                           school
# sacred heart primary school    1133.0
# sacred heart primary school    1049.0
# Name: icsea, dtype: float64
# 80668                                                                                                                                                                                                                 school
# st john's school    1119.0
# st john's school     907.0
# Name: icsea, dtype: float64
# 80756                                                                                                                                                                                                 school
# st paul's primary school    1153.0
# st paul's primary school    1015.0
# Name: icsea, dtype: float64
# 80893                                                                                                                                                                                                             school
# st brigid's school    1030.0
# st brigid's school    1004.0
# Name: icsea, dtype: float64
# 81012  school
# st joseph's school    1000.0
# st joseph's school     781.0
# st joseph's school     908.0
# st joseph's school    1022.0
# st joseph's school    1022.0
# st joseph's school    1084.0
# st joseph's school     947.0
# st joseph's school     976.0
# st joseph's school     708.0
# Name: icsea, dtype: float64
#
#        secondaryICSEA
# 155             942.0
# 234             916.0
# 326             915.0
# 378             896.0
# 425             914.0
# ...               ...
# 80544             NaN
# 80668           915.0
# 80756          1097.0
# 80893           984.0
# 81012           978.0
#
# [698 rows x 41 columns]

# %%
train[['primary', 'primaryICSEA','secondary','secondaryICSEA']].head()
# Out:
#                      primary primaryICSEA                        secondary  \
# 0  maida vale primary school       1021.0     darling range sports college
# 1      coogee primary school       1065.0             divine mercy college
# 2   redcliffe primary school        994.0  alta-1 college - belmont campus
# 3      butler primary school        976.0                   butler college
# 4  pegs creek primary school        870.0      karratha senior high school
#
#    secondaryICSEA
# 0           971.0
# 1          1054.0
# 2             NaN
# 3           976.0
# 4           916.0

# %% [markdown]
# # One Hot Encoding

# %%
def ohe_transform(df, transformer, cat_cols):
    '''
    - Performs one hot encoding on selected categorical variables on a df
    - Encoder must be made prior to running this function
    '''
    # Encoding
    transformed = transformer.transform(df)
    # Reformatting OHE column names
    transformer_names = transformer.get_feature_names_out()
    ohe_names = [name.split('__', 1)[-1] for name in transformer_names]
    # Converting back to dataframe
    transformed_df = pd.DataFrame(transformed.toarray(), columns=ohe_names)
    transformed_df.index = df.index
    # Joining OHE df with other numerical features
    df = pd.concat([df, transformed_df], axis=1)
    df = df.drop(columns=cat_cols)
    
    return df

# %% [markdown]
# ### features

# %%
feature_dict = {}

for listing in train['features']:
    for feature in listing:
        if feature in feature_dict.keys():
            feature_dict[feature] += 1
        else:
            feature_dict[feature] = 1

feature_dict = {key: value for key, value in feature_dict.items() if value >= 1500}

# %%
dict(sorted(feature_dict.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'air conditioning': 19707,
#  'ensuite': 13612,
#  'secure parking': 11808,
#  'built in wardrobes': 10293,
#  'dishwasher': 7431,
#  'fully fenced': 7207,
#  'close to shops': 5749,
#  'close to schools': 5668,
#  'built-in wardrobes': 5576,
#  'close to transport': 5276,
#  'shed': 5003,
#  'garden / courtyard': 4354,
#  'study': 4094,
#  'internal laundry': 3709,
#  'balcony / deck': 3565,
#  'garden': 3472,
#  'floorboards': 3465,
#  'bath': 3307,
#  'swimming pool': 3234,
#  'solar panels': 2871,
#  'gas': 2558,
#  'remote garage': 2540,
#  'heating': 2470,
#  'alarm system': 2441,
#  'fireplace(s)': 2269,
#  'outdoor entertaining': 2061,
#  'pets allowed': 2007,
#  'formal lounge': 1696,
#  'broadband internet access': 1608}

# %%
# Filter the features we want to encode based on feature_dict keys
selected_features = list(feature_dict.keys())

# Perform one-hot encoding
for feature in selected_features:
    train[feature] = train['features'].apply(lambda x: 1 if feature in x else 0)
    test[feature] = test['features'].apply(lambda x: 1 if feature in x else 0)

# %%
train.columns
# Out:
# Index(['listingId', 'unitNumber', 'streetNumber', 'street', 'suburb', 'state',
#        'postcode', 'bathrooms', 'bedrooms', 'parking', 'landArea', 'latitude',
#        'longitude', 'features', 'agency', 'propertyType', 'promoLevel',
#        'soldMonth', 'soldYear', 'daysListed', 'inspectionsCount', 'isRural',
#        'hasDescription', 'hasFloorplan', 'hasDisplayPrice', 'hasPhoto',
#        'photoCount', 'suburb_medianPrice', 'suburb_medianRentPrice',
#        'suburb_entryLevelPrice', 'suburb_luxuryLevelPrice', 'primary',
#        'primaryDistance', 'primaryType', 'secondary', 'secondaryDistance',
#        'secondaryType', 'listingUrl', 'soldPrice', 'primaryICSEA',
#        'secondaryICSEA', 'air conditioning', 'built-in wardrobes',
#        'close to schools', 'close to shops', 'garden', 'secure parking',
#        'ensuite', 'built in wardrobes', 'pets allowed', 'bath', 'dishwasher',
#        'garden / courtyard', 'close to transport', 'fully fenced', 'shed',
#        'floorboards', 'formal lounge', 'internal laundry', 'heating', 'study',
#        'alarm system', 'solar panels', 'outdoor entertaining', 'swimming pool',
#        'broadband internet access', 'balcony / deck', 'remote garage', 'gas',
#        'fireplace(s)'],
#       dtype='object')

# %%
# Renaming the encoded columns
column_mapping = {
    'fully fenced': 'feature_fully_fenced',
    'secure parking': 'feature_secure_parking',
    'air conditioning': 'feature_air_conditioning',
    'close to shops': 'feature_close_to_shops',
    'close to schools': 'feature_close_to_schools',
    'built in wardrobes': 'feature_built_in_wardrobes',
    'outdoor entertaining': 'feature_outdoor_entertaining',
    'remote garage': 'feature_remote_garage',
    'heating': 'feature_heating',
    'study': 'feature_study',
    'shed': 'feature_shed',
    'built-in wardrobes': 'feature_built_in_wardrobes',
    'dishwasher': 'feature_dishwasher',
    'floorboards': 'feature_floorboards',
    'internal laundry': 'feature_internal_laundry',
    'pets allowed': 'feature_pets_allowed',
    'bath': 'feature_bath',
    'fireplace(s)': 'feature_fireplace',
    'alarm system': 'feature_alarm_system',
    'balcony / deck': 'feature_balcony',
    'ensuite': 'feature_ensuite',
    'close to transport': 'feature_close_to_transport',
    'formal lounge': 'feature_formal_lounge',
    'garden': 'feature_garden',
    'solar panels': 'feature_solar_panels',
    'gas': 'feature_gas',
    'garden / courtyard': 'feature_courtyard',
    'broadband internet access': 'feature_broadband_internet',
    'swimming pool': 'feature_swimming_pool'
}

# Apply the renaming
train.rename(columns=column_mapping, inplace=True)
test.rename(columns=column_mapping, inplace=True)

# %%
train.columns
# Out:
# Index(['listingId', 'unitNumber', 'streetNumber', 'street', 'suburb', 'state',
#        'postcode', 'bathrooms', 'bedrooms', 'parking', 'landArea', 'latitude',
#        'longitude', 'features', 'agency', 'propertyType', 'promoLevel',
#        'soldMonth', 'soldYear', 'daysListed', 'inspectionsCount', 'isRural',
#        'hasDescription', 'hasFloorplan', 'hasDisplayPrice', 'hasPhoto',
#        'photoCount', 'suburb_medianPrice', 'suburb_medianRentPrice',
#        'suburb_entryLevelPrice', 'suburb_luxuryLevelPrice', 'primary',
#        'primaryDistance', 'primaryType', 'secondary', 'secondaryDistance',
#        'secondaryType', 'listingUrl', 'soldPrice', 'primaryICSEA',
#        'secondaryICSEA', 'feature_air_conditioning',
#        'feature_built_in_wardrobes', 'feature_close_to_schools',
#        'feature_close_to_shops', 'feature_garden', 'feature_secure_parking',
#        'feature_ensuite', 'feature_built_in_wardrobes', 'feature_pets_allowed',
#        'feature_bath', 'feature_dishwasher', 'feature_courtyard',
#        'feature_close_to_transport', 'feature_fully_fenced', 'feature_shed',
#        'feature_floorboards', 'feature_formal_lounge',
#        'feature_internal_laundry', 'feature_heating', 'feature_study',
#        'feature_alarm_system', 'feature_solar_panels',
#        'feature_outdoor_entertaining', 'feature_swimming_pool',
#        'feature_broadband_internet', 'feature_balcony',
#        'feature_remote_garage', 'feature_gas', 'feature_fireplace'],
#       dtype='object')

# %% [markdown]
# ### propertyType, promoLevel

# %%
cat_cols = ['propertyType','promoLevel']
# Create encoder handle_unknown ensures that unseen values in the test set are ignored
t = make_column_transformer((OneHotEncoder(handle_unknown='ignore'), 
                                      ['propertyType','promoLevel','primaryType','secondaryType']))
t.fit(train)
# Out:
# ColumnTransformer(transformers=[('onehotencoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['propertyType', 'promoLevel', 'primaryType',
#                                   'secondaryType'])])

# %%
test.columns
# Out:
# Index(['listingId', 'unitNumber', 'streetNumber', 'street', 'suburb', 'state',
#        'postcode', 'bathrooms', 'bedrooms', 'parking', 'landArea', 'latitude',
#        'longitude', 'features', 'agency', 'propertyType', 'promoLevel',
#        'soldMonth', 'soldYear', 'daysListed', 'inspectionsCount', 'isRural',
#        'hasDescription', 'hasFloorplan', 'hasDisplayPrice', 'hasPhoto',
#        'photoCount', 'suburb_medianPrice', 'suburb_medianRentPrice',
#        'suburb_entryLevelPrice', 'suburb_luxuryLevelPrice', 'primary',
#        'primaryDistance', 'primaryType', 'secondary', 'secondaryDistance',
#        'secondaryType', 'listingUrl', 'soldPrice', 'primaryICSEA',
#        'secondaryICSEA', 'feature_air_conditioning',
#        'feature_built_in_wardrobes', 'feature_close_to_schools',
#        'feature_close_to_shops', 'feature_garden', 'feature_secure_parking',
#        'feature_ensuite', 'feature_built_in_wardrobes', 'feature_pets_allowed',
#        'feature_bath', 'feature_dishwasher', 'feature_courtyard',
#        'feature_close_to_transport', 'feature_fully_fenced', 'feature_shed',
#        'feature_floorboards', 'feature_formal_lounge',
#        'feature_internal_laundry', 'feature_heating', 'feature_study',
#        'feature_alarm_system', 'feature_solar_panels',
#        'feature_outdoor_entertaining', 'feature_swimming_pool',
#        'feature_broadband_internet', 'feature_balcony',
#        'feature_remote_garage', 'feature_gas', 'feature_fireplace'],
#       dtype='object')

# %%
train = ohe_transform(train,t,cat_cols)
test = ohe_transform(test,t,cat_cols)

# %%
train.columns
# Out:
# Index(['listingId', 'unitNumber', 'streetNumber', 'street', 'suburb', 'state',
#        'postcode', 'bathrooms', 'bedrooms', 'parking', 'landArea', 'latitude',
#        'longitude', 'features', 'agency', 'soldMonth', 'soldYear',
#        'daysListed', 'inspectionsCount', 'isRural', 'hasDescription',
#        'hasFloorplan', 'hasDisplayPrice', 'hasPhoto', 'photoCount',
#        'suburb_medianPrice', 'suburb_medianRentPrice',
#        'suburb_entryLevelPrice', 'suburb_luxuryLevelPrice', 'primary',
#        'primaryDistance', 'primaryType', 'secondary', 'secondaryDistance',
#        'secondaryType', 'listingUrl', 'soldPrice', 'primaryICSEA',
#        'secondaryICSEA', 'feature_air_conditioning',
#        'feature_built_in_wardrobes', 'feature_close_to_schools',
#        'feature_close_to_shops', 'feature_garden', 'feature_secure_parking',
#        'feature_ensuite', 'feature_built_in_wardrobes', 'feature_pets_allowed',
#        'feature_bath', 'feature_dishwasher', 'feature_courtyard',
#        'feature_close_to_transport', 'feature_fully_fenced', 'feature_shed',
#        'feature_floorboards', 'feature_formal_lounge',
#        'feature_internal_laundry', 'feature_heating', 'feature_study',
#        'feature_alarm_system', 'feature_solar_panels',
#        'feature_outdoor_entertaining', 'feature_swimming_pool',
#        'feature_broadband_internet', 'feature_balcony',
#        'feature_remote_garage', 'feature_gas', 'feature_fireplace',
#        'propertyType_apartment', 'propertyType_house',
#        'propertyType_townhouse', 'propertyType_unknown', 'promoLevel_elite',
#        'promoLevel_elite_pp', 'promoLevel_premium_plus', 'promoLevel_standard',
#        'promoLevel_standard_pp', 'primaryType_catholic',
#        'primaryType_government', 'primaryType_private',
#        'secondaryType_catholic', 'secondaryType_government',
#        'secondaryType_private'],
#       dtype='object')

# %% [markdown]
# # Binarization

# %%
binary_cols = ['isRural','hasDescription', 'hasFloorplan', 'hasDisplayPrice', 'hasPhoto']

# Binarizing all columns
for col in binary_cols:
    train[col] = train[col].astype(int)
    test[col] = test[col].astype(int)

# %% [markdown]
# # Constant features
# Removing features with vary small variance. These features don't provide any additional advantage to machine learning models

# %%
# Select only numeric columns
numeric_train = train.select_dtypes(include=["number"])
numeric_test = test.select_dtypes(include=["number"])

# %%
# Apply VarianceThreshold to numeric columns
sel = VarianceThreshold(threshold=0.01)  # 0.1 indicates 99% of observations approximately
sel.fit(numeric_train)  # Fit only on numeric columns

# Get the remaining features
features_to_keep = numeric_train.columns[sel.get_support()]
features_removed = numeric_train.columns[~sel.get_support()]  # Features not selected

# %%
# Transform the numeric data
numeric_train = sel.transform(numeric_train)
numeric_test = sel.transform(numeric_test)

# %%
# Transform the arrays back to DataFrames
numeric_train = pd.DataFrame(numeric_train, columns=features_to_keep)
numeric_test = pd.DataFrame(numeric_test, columns=features_to_keep)

# %%
# Combine back with non-numeric columns
train = pd.concat([train.select_dtypes(exclude=["number"]), numeric_train], axis=1)
test = pd.concat([test.select_dtypes(exclude=["number"]), numeric_test], axis=1)

train.shape, test.shape
# Out:
# ((81088, 77), (17378, 77))

# %%
features_removed
# Out:
# Index(['inspectionsCount', 'hasDescription', 'hasDisplayPrice', 'hasPhoto',
#        'propertyType_unknown', 'promoLevel_elite_pp'],
#       dtype='object')

# %%
train.columns
# Out:
# Index(['unitNumber', 'streetNumber', 'street', 'suburb', 'state', 'features',
#        'agency', 'primary', 'primaryType', 'secondary', 'secondaryType',
#        'listingUrl', 'primaryICSEA', 'listingId', 'postcode', 'bathrooms',
#        'bedrooms', 'parking', 'landArea', 'latitude', 'longitude', 'soldMonth',
#        'soldYear', 'daysListed', 'isRural', 'hasFloorplan', 'photoCount',
#        'suburb_medianPrice', 'suburb_medianRentPrice',
#        'suburb_entryLevelPrice', 'suburb_luxuryLevelPrice', 'primaryDistance',
#        'secondaryDistance', 'soldPrice', 'secondaryICSEA',
#        'feature_air_conditioning', 'feature_built_in_wardrobes',
#        'feature_close_to_schools', 'feature_close_to_shops', 'feature_garden',
#        'feature_secure_parking', 'feature_ensuite',
#        'feature_built_in_wardrobes', 'feature_pets_allowed', 'feature_bath',
#        'feature_dishwasher', 'feature_courtyard', 'feature_close_to_transport',
#        'feature_fully_fenced', 'feature_shed', 'feature_floorboards',
#        'feature_formal_lounge', 'feature_internal_laundry', 'feature_heating',
#        'feature_study', 'feature_alarm_system', 'feature_solar_panels',
#        'feature_outdoor_entertaining', 'feature_swimming_pool',
#        'feature_broadband_internet', 'feature_balcony',
#        'feature_remote_garage', 'feature_gas', 'feature_fireplace',
#        'propertyType_apartment', 'propertyType_house',
#        'propertyType_townhouse', 'promoLevel_elite', 'promoLevel_premium_plus',
#        'promoLevel_standard', 'promoLevel_standard_pp', 'primaryType_catholic',
#        'primaryType_government', 'primaryType_private',
#        'secondaryType_catholic', 'secondaryType_government',
#        'secondaryType_private'],
#       dtype='object')

# %% [markdown]
# # Geospatial features

# %%
train.dropna(inplace=True)

# %% [markdown]
# ### coastDistance
# For each property listing, find the distance to the nearest coastline

# %%
# https://www.naturalearthdata.com/downloads/10m-physical-vectors/
# Load coastline data 
coastline = gpd.read_file("/Users/tristangarcia/desktop/hp-pred_data/ne_50m_coastline/ne_50m_coastline.shp")
# Reproject coastline to EPSG:3395 (meters)
coastline = coastline.to_crs(epsg=3395)

# %%
def convert_to_gdf(df):
    # Convert df to GeoDataFrame
    df['geometry'] = df.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)
    gdf = gpd.GeoDataFrame(df, geometry='geometry', crs="EPSG:4326")
    # Reproject train data to EPSG:3395 (meters)
    gdf = gdf.to_crs(epsg=3395)
    
    return df

# %%
def get_coastDistance(gdf,df):
    # Calculate distances to the nearest coastline
    gdf['coastDistance'] = gdf.geometry.apply(
        lambda point: coastline.distance(point).min()
    )

    # Assigning a new variable to the original df
    df['coastDistance'] = gdf['coastDistance']
    # Removing helper column
    df.drop(columns=['geometry'], inplace=True)
    
    return df

# %%
# Converting train and test sets to geodataframes
train_gdf = convert_to_gdf(train)
test_gdf = convert_to_gdf(test)

# %%
# Creating new coastDistance variable
train = get_coastDistance(train_gdf,train)
test = get_coastDistance(test_gdf,test)

# %%
# Check results
print(train[['latitude', 'longitude', 'coastDistance']].head())
# Out:
#      latitude   longitude  coastDistance
# 7  -31.982767  115.909631  572456.649263
# 16 -31.895995  115.756919  572456.509864
# 20 -31.941955  115.838458  572456.583952
# 27 -32.094748  115.781421  572456.702466
# 29 -31.948803  115.845545  572456.593021

# %% [markdown]
# ### cbdDistance
# For each property listing, find the distance to Perth CBD

# %%
# CBD coordinates
perth_cbd_lat = 31.9514
perth_cbd_lon = 115.8617  

# Create a GeoDataFrame for the CBD point
perth_cbd = gpd.GeoDataFrame(
    geometry=[Point(perth_cbd_lon, perth_cbd_lat)],
    crs="EPSG:4326"
).to_crs(epsg=3395)  # Reproject to EPSG:3395 (meters)

# %%
def get_cbdDistance(gdf,df):
    # Calculate distance to Perth CBD in meters
    gdf['cbdDistance'] = gdf.geometry.apply(
        lambda point: perth_cbd.distance(point).min()
    )

    # Assigning a new variable to the original df
    df['cbdDistance'] = gdf['cbdDistance']
    # Removing helper column
    df.drop(columns=['geometry'], inplace=True)
    
    return df

# %%
# Converting train and test sets to geodataframes
train_gdf = convert_to_gdf(train)
test_gdf = convert_to_gdf(test)

# %%
# Creating new cbdDistance variable
train = get_cbdDistance(train_gdf,train)
test = get_cbdDistance(test_gdf,test)

# %%
# Check results
print(train[['latitude', 'longitude', 'cbdDistance']].head())
# Out:
#      latitude   longitude   cbdDistance
# 7  -31.982767  115.909631  1.342729e+07
# 16 -31.895995  115.756919  1.342729e+07
# 20 -31.941955  115.838458  1.342729e+07
# 27 -32.094748  115.781421  1.342729e+07
# 29 -31.948803  115.845545  1.342729e+07

# %% [markdown]
# ### Spatial region clustering

# %%
# Create geometry column with shapely Points
train['geometry'] = train.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)

# Convert to GeoDataFrame
gdf = gpd.GeoDataFrame(train, geometry='geometry', crs="EPSG:4326")  # WGS84 CRS

# Extract latitude and longitude as input for clustering
coords = train[['latitude', 'longitude']]
# Fit K-Means
km = KMeans(n_clusters=20)
km.fit(coords)
train['cluster_id'] = km.predict(coords)

# Add cluster_id to GeoDataFrame
gdf['cluster_id'] = train['cluster_id']

# Visualize clusters using GeoPandas
# Plot clusters with a unique color for each cluster
fig, ax = plt.subplots(figsize=(12, 10))
gdf.plot(column='cluster_id', cmap='viridis', legend=True, ax=ax, markersize=5)
plt.title('K-Means Clustering of Houses (Latitude and Longitude)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
train['cluster_id'].value_counts()
# Out:
# cluster_id
# 0     8430
# 19    2986
# 12     668
# 17     503
# 4      340
# 14     295
# 7      228
# 1      210
# 6      166
# 5       89
# 2       70
# 15      69
# 10      60
# 13      51
# 9       37
# 3       33
# 11      23
# 8       21
# 18      19
# 16       7
# Name: count, dtype: int64

# %% [markdown]
# # Standardisation

# %%
print(train[std_features].dtypes)
# Out:
# bathrooms                  float64
# bedrooms                   float64
# parking                    float64
# landArea                   float64
# daysListed                 float64
# photoCount                 float64
# suburb_medianPrice         float64
# suburb_medianRentPrice     float64
# suburb_entryLevelPrice     float64
# suburb_luxuryLevelPrice    float64
# primaryDistance            float64
# secondaryDistance          float64
# coastDistance              float64
# cbdDistance                float64
# primaryICSEA                object
# secondaryICSEA             float64
# dtype: object

# %%
train['primaryICSEA'].value_counts()
# Out:
# primaryICSEA
# 1110.0                                                                                                            1118
# 1121.0                                                                                                             599
# 0                                                                                                                  596
# 1060.0                                                                                                             577
# 1085.0                                                                                                             476
#                                                                                                                   ...
# school
# st john's school    1119.0
# st john's school     907.0
# Name: icsea, dtype: float64                             1
# school
# sacred heart primary school    1133.0
# sacred heart primary school    1049.0
# Name: icsea, dtype: float64       1
# school
# sacred heart primary school    1133.0
# sacred heart primary school    1049.0
# Name: icsea, dtype: float64       1
# school
# sacred heart primary school    1133.0
# sacred heart primary school    1049.0
# Name: icsea, dtype: float64       1
# school
# st paul's primary school    1153.0
# st paul's primary school    1015.0
# Name: icsea, dtype: float64             1
# Name: count, Length: 780, dtype: int64

# %%
std_features = ['bathrooms', 'bedrooms', 'parking', 'landArea','daysListed','photoCount', 'suburb_medianPrice',
                'suburb_medianRentPrice', 'suburb_entryLevelPrice','suburb_luxuryLevelPrice','primaryDistance',
                'secondaryDistance','coastDistance', 'cbdDistance', 'primaryICSEA','secondaryICSEA']
scaler = StandardScaler()
scaler.fit(train[std_features])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:248, in _coerce_method.<locals>.wrapper(self)
#     247     return converter(self.iloc[0])
# --> 248 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/vr/skwvh_8x0gzcmpxx950wbv9c0000gn/T/ipykernel_41079/452953629.py in ?()
#       1 std_features = ['bathrooms', 'bedrooms', 'parking', 'landArea','daysListed','photoCount', 'suburb_medianPrice',
#       2                 'suburb_medianRentPrice', 'suburb_entryLevelPrice','suburb_luxuryLevelPrice','primaryDistance',
#       3                 'secondaryDistance','coastDistance', 'cbdDistance', 'primaryICSEA','secondaryICSEA']
#       4 scaler = StandardScaler()
# ----> 5 scaler.fit(train[std_features])
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     874             Fitted scaler.
#     875         """
#     876         # Reset internal state before fitting
#     877         self._reset()
# --> 878         return self.partial_fit(X, y, sample_weight)
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     910         self : object
#     911             Fitted scaler.
#     912         """
#     913         first_call = not hasattr(self, "n_samples_seen_")
# --> 914         X = self._validate_data(
#     915             X,
#     916             accept_sparse=("csr", "csc"),
#     917             dtype=FLOAT_DTYPES,
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     741         # Use NumPy API to support order
#     742         if copy is True:
#     743             array = numpy.array(array, order=order, dtype=dtype)
#     744         else:
# --> 745             array = numpy.asarray(array, order=order, dtype=dtype)
#     746
#     747         # At this point array is a NumPy ndarray. We convert it to an array
#     748         # container that is consistent with the input's namespace.
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: setting an array element with a sequence.

# %%
train[std_features] = scaler.transform(train[std_features])
test[std_features] = scaler.transform(test[std_features])

# %% [markdown]
# # Irrelevant features

# %%
train.columns

# %%
# Dropping the irrelevant columns
train = train.drop(columns=['listingId', 'unitNumber', 'streetNumber', 'street', 'state',
                            'postcode', 'agency', 'suburb', 'latitude', 'longitude', 'features', 
                            'propertyType', 'promoLevel', 'primary', 'secondary', 'listingUrl'])

test = test.drop(columns=['listingId', 'unitNumber', 'streetNumber', 'street', 'state',
                          'postcode', 'agency', 'suburb', 'latitude', 'longitude', 'features', 
                          'propertyType', 'promoLevel', 'primary', 'secondary', 'listingUrl'])

# %% [markdown]
# # Removing the rest of the missing values
# Some null values still remain even after imputation as there isn't enough information to impute on other values

# %%
train.dropna(inplace=True)
test.dropna(inplace=True)

train.reset_index(drop=True, inplace=True)
test.reset_index(drop=True, inplace=True)

print(train.shape)
print(test.shape)

# %% [markdown]
# # Duplicates removal

# %%
# Number of duplicates in training set
print(len(train) - len(train.loc[train.drop(columns=['features']).drop_duplicates().index]))
train = train.loc[train.drop(columns=['features']).drop_duplicates().index]
# Number of duplicates in validation set
print(len(test) - len(test.loc[test.drop(columns=['features']).drop_duplicates().index]))
test = test.loc[test.drop(columns=['features']).drop_duplicates().index]
