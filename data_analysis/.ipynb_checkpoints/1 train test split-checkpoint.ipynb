# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
path = '/Users/tristangarcia/desktop/hp-pred_data/data/wa_data/'
data = pd.read_csv(f'{path}wa_data.csv')
# Out:
# /var/folders/vr/skwvh_8x0gzcmpxx950wbv9c0000gn/T/ipykernel_41765/3833328733.py:2: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(f'{path}wa_data.csv')

# %%
# Dropping null values from isRural to allow for a stratified train test split
x = len(data[data['isRural'].isnull()])
print(f'Dropping {x} null rows from isRural')
data.dropna(subset=['isRural'], inplace=True)
                  
# train test split
train,test = train_test_split(data, test_size=0.3, stratify=data['isRural'],
                              random_state=222, shuffle=True)
# validation split
validation,test = train_test_split(test, test_size=0.5, stratify=test['isRural'],
                                  random_state=222, shuffle=True)
# Out:
# Dropping 12 null rows from isRural

# %% [markdown]
# # Train

# %%
train.shape
# Out:
# (88064, 39)

# %%
train.head()
# Out:
#            listingId unitNumber streetNumber               street  \
# 122230  2.012855e+09        NaN           81    Sutherland Street
# 90041   2.016666e+09        NaN           16  North Yunderup Road
# 76053   2.017181e+09        NaN          NaN                  NaN
# 76178   2.016826e+09        174           34        Quarry Street
# 30758   2.017975e+09        NaN         120A       Peninsula Road
#
#                 suburb state  postcode  bathrooms  bedrooms  parking  ...  \
# 122230    Port Hedland    WA    6721.0          2         4        2  ...
# 90041   North Yunderup    WA    6208.0          2         4        2  ...
# 76053        Fremantle    WA    6160.0          1         2        1  ...
# 76178        Fremantle    WA    6160.0          2         2        2  ...
# 30758         Maylands    WA    6051.0          1         3        2  ...
#
#         suburb_entryLevelPrice  suburb_luxuryLevelPrice  \
# 122230                580000.0                1300000.0
# 90041                      0.0                      0.0
# 76053                 350000.0                 830000.0
# 76178                 350000.0                 830000.0
# 30758                 485000.0                1091000.0
#
#                                   primary primaryDistance primaryType  \
# 122230        Port Hedland Primary School     1494.829156  Government
# 90041         Austin Cove Baptist College     2090.077434     Private
# 76053       East Fremantle Primary School      671.284593  Government
# 76178         St Patrick's Primary School      515.380645    Catholic
# 30758   Maylands Peninsula Primary School      614.539766  Government
#
#                                                 secondary secondaryDistance  \
# 122230                                                NaN               NaN
# 90041   Austin Cove Baptist College - California Cresc...       2068.941801
# 76053                         Christian Brothers' College        712.514537
# 76178                         Christian Brothers' College        488.851259
# 30758               Bold Park Community School - Maylands       1065.109698
#
#         secondaryType                                         listingUrl  \
# 122230            NaN  https://www.domain.com.au/81-sutherland-street...
# 90041         Private  https://www.domain.com.au/16-north-yunderup-ro...
# 76053        Catholic  https://www.domain.com.au/fremantle-wa-6160-20...
# 76178        Catholic  https://www.domain.com.au/174-34-quarry-street...
# 30758         Private  https://www.domain.com.au/120a-peninsula-road-...
#
#         soldPrice
# 122230   580000.0
# 90041    395000.0
# 76053    330000.0
# 76178    595000.0
# 30758    600000.0
#
# [5 rows x 39 columns]

# %% [markdown]
# # Validation

# %%
validation.shape
# Out:
# (18871, 39)

# %%
validation.head()
# Out:
#            listingId unitNumber streetNumber             street      suburb  \
# 108395  2.018041e+09        NaN           38       Hofrad Court     Yakamia
# 71901   2.018627e+09        NaN            6          Ben Place   Willetton
# 2541    2.019437e+09        NaN       29/990  Wellington Street  West Perth
# 120293  2.016331e+09        NaN      Lot 472         Osprey Way     Exmouth
# 30468   2.018707e+09         61           12        Wall Street    Maylands
#
#        state  postcode  bathrooms  bedrooms  parking  ...  \
# 108395    WA    6330.0          1         3        1  ...
# 71901     WA    6155.0          2         5        2  ...
# 2541      WA    6005.0          1         2        1  ...
# 120293    WA    6707.0          0         0        0  ...
# 30468     WA    6051.0          1         3        1  ...
#
#         suburb_entryLevelPrice  suburb_luxuryLevelPrice  \
# 108395                355000.0                 700000.0
# 71901                 928000.0                1650000.0
# 2541                  350000.0                 660000.0
# 120293                     0.0                      0.0
# 30468                 390000.0                1150000.0
#
#                                   primary primaryDistance primaryType  \
# 108395             Yakamia Primary School      380.520775  Government
# 71901             Rostrata Primary School     1275.866405  Government
# 2541      West Leederville Primary School     1143.280083  Government
# 120293                                NaN             NaN         NaN
# 30468   Maylands Peninsula Primary School     1022.592141  Government
#
#                                     secondary secondaryDistance  \
# 108395  Alta-1 College - Albany Senior School        630.124119
# 71901            Willetton Senior High School       1013.644257
# 2541                        Bob Hawke College        906.194512
# 120293                                    NaN               NaN
# 30468   Bold Park Community School - Maylands       1974.280506
#
#         secondaryType                                         listingUrl  \
# 108395        Private  https://www.domain.com.au/38-hofrad-court-yaka...
# 71901      Government  https://www.domain.com.au/6-ben-place-willetto...
# 2541       Government  https://www.domain.com.au/29-990-wellington-st...
# 120293            NaN  https://www.domain.com.au/lot-472-osprey-way-e...
# 30468         Private  https://www.domain.com.au/61-12-wall-street-ma...
#
#         soldPrice
# 108395   395000.0
# 71901   1350269.0
# 2541     495000.0
# 120293   350000.0
# 30468    410000.0
#
# [5 rows x 39 columns]

# %% [markdown]
# # Test

# %%
test.shape
# Out:
# (18871, 39)

# %%
test.head()
# Out:
#            listingId unitNumber streetNumber  \
# 104364  2.017315e+09        NaN       Lot 22
# 122702  2.018576e+09        NaN           10
# 90886   2.019453e+09        NaN            1
# 34463   2.018812e+09        NaN            5
# 94371   2.016726e+09        NaN          233
#
#                                        street          suburb state  postcode  \
# 104364  of Lot 1001 Redgate Road, Witchcliffe  Margaret River    WA    6285.0
# 122702                         Banksia Street   South Hedland    WA    6722.0
# 90886                        Ivanhoe Crescent          Falcon    WA    6210.0
# 34463                           Platinum Road          Dayton    WA    6055.0
# 94371                   Atkinson Street North          Collie    WA    6225.0
#
#         bathrooms  bedrooms  parking  ...  suburb_entryLevelPrice  \
# 104364          0         0        0  ...                     0.0
# 122702          2         4        2  ...                340000.0
# 90886           1         3        6  ...                440000.0
# 34463           2         4        2  ...                548000.0
# 94371           0         0        0  ...                     0.0
#
#         suburb_luxuryLevelPrice                                 primary  \
# 104364                      0.0  St Thomas More Catholic Primary School
# 122702                 770000.0                   Cassia Primary School
# 90886                  949000.0                   Falcon Primary School
# 34463                  905000.0                   Dayton Primary School
# 94371                       0.0                      St Brigid's School
#
#        primaryDistance primaryType  \
# 104364      437.168642    Catholic
# 122702      489.179096  Government
# 90886       433.382367  Government
# 34463       192.372005  Government
# 94371       737.948278    Catholic
#
#                                          secondary secondaryDistance  \
# 104364           Margaret River Senior High School       1207.335867
# 122702                  Hedland Senior High School       2001.713589
# 90886                           Halls Head College       5790.369254
# 34463   Youth Futures Community School (Caversham)       2770.788568
# 94371                    Collie Senior High School       2223.825716
#
#         secondaryType                                         listingUrl  \
# 104364     Government  https://www.domain.com.au/lot-22-of-lot-1001-r...
# 122702     Government  https://www.domain.com.au/10-banksia-street-so...
# 90886      Government  https://www.domain.com.au/1-ivanhoe-crescent-f...
# 34463         Private  https://www.domain.com.au/5-platinum-road-dayt...
# 94371      Government  https://www.domain.com.au/233-atkinson-street-...
#
#         soldPrice
# 104364   255000.0
# 122702   689000.0
# 90886    678000.0
# 34463    540000.0
# 94371     36000.0
#
# [5 rows x 39 columns]

# %% [markdown]
# # Writing to csv

# %%
train.to_csv(f'{path}wa_train.csv', index=False)
validation.to_csv(f'{path}wa_validation.csv', index=False)
test.to_csv(f'{path}wa_test.csv', index=False)
